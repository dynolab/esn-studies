# %%
import os
import sys
sys.path.append(os.getcwd())

import restools
from comsdk.research import Research

import matplotlib.pyplot as plt
import pickle
import numpy as np
import pandas as pd

# %%
from pyESN import ESN, optimal_esn
from skesn.esn import EsnForecaster

# %%
Gainsboro   =	'#DCDCDC'
LightGrey   =	'#D3D3D3'
Silver      =	'#C0C0C0'
DarkGray    =	'#A9A9A9'
Gray        =	'#808080'
DimGray     =	'#696969'
Black       =	'#000000'

# %%
res = Research.open('RC_MOEHLIS')
task_num = 42

data = []
time = []
n_files = 100

for num_data in range(n_files):
    with open(os.path.join(res.get_task_path(task_num), str(num_data+1)), 'rb') as a:
        b = pickle.load(a)
    data.append(b['timeseries'])
    time.append(b['time'])
# Out:
# Loaded research at C:\Users\ovann\Documents\Researches\2021-04-30-predicting-transition-to-turbulence-using-esn
# Number of tasks in the current research: 5059

# %%
df_time_len = pd.DataFrame(
    {
        'time_len': [len(i) for i in time],
        'file_name': [i+1 for i in range(n_files)]
    })

df_time_len.sort_values(by=['time_len'], inplace=True)

# %%
plt.figure(figsize=(15,6))
plt.plot(range(n_files), df_time_len.time_len, '.-', label='№ файла', color=Gray)
for i, j, k in zip(df_time_len.time_len, df_time_len.file_name, range(n_files)):
    plt.text(k, i+100+(k%5)*200, j, fontsize=10.)
plt.grid()
plt.ylabel('Time len')
plt.xlabel('Position')
plt.legend()

# %%
files = [66-1, 77-1, 48-1, 60-1,]
N = len(files)

plt.figure(figsize=(15,3*N))

for i, n in zip(range(N), files):
    datalen = len(time[n])
    trainlen = int(len(time[n])*0.8)
    testlen = datalen - trainlen

    training_timeseries = data[n][:trainlen]
    test_timeseries_set = [data[n][trainlen:]]

    plt.subplot(N,1,i+1)
    
    plt.plot(time[n][:trainlen], training_timeseries[:, 0], '-', color=Black,label='Train')
    plt.plot(time[n][trainlen:], test_timeseries_set[0][:, 0], '--', color=Gray, label='Test')

    plt.xlabel(r'$L_{timeseries}$', fontsize=16)
    plt.ylabel(fr'$a_{1}$', fontsize=16)
    
    plt.legend()
    plt.grid()

# %%
n = 60-1
N = 0

plt.figure(figsize=(15,3))
plt.plot(time[n], data[n][:, N], '-', color=Black, label='Timseries')

plt.xlabel(r'$L_{timeseries}$', fontsize=16)
plt.ylabel(fr'$a_{1}$', fontsize=16)
plt.legend()
plt.grid()

plt.figure(figsize=(15,3))
plt.plot(time[n][:-1], np.diff(data[n][:, N]), '-', color=Black, label='Diff Timseries')

plt.xlabel(r'$L_{timeseries}$', fontsize=16)
plt.ylabel(fr'$a_{1}$', fontsize=16)
plt.legend()
plt.grid()

# %%
def calculate_rsi(prices, n=30):
    deltas = np.diff(prices)
    seed = deltas[:n+1]
    up = seed[seed >= 0].sum() / n
    down = -seed[seed < 0].sum() / n
    rs = up / down
    rsi = np.zeros_like(prices)
    rsi[:n] = 100. - 100. / (1. + rs)

    for i in range(n, len(prices)):
        delta = deltas[i-1]
        if delta > 0:
            upval = delta
            downval = 0.
        else:
            upval = 0.
            downval = -delta
        up = (up * (n-1) + upval) / n
        down = (down * (n-1) + downval) / n
        rs = up / down
        rsi[i] = 100. - 100. / (1. + rs)

    return rsi

# %%
files = [66-1, 77-1, 48-1, 60-1,]
N = len(files)

plt.figure(figsize=(15,3*N))

for i, n in zip(range(N), files):
    datalen = len(time[n])
    trainlen = datalen - 935
    testlen = datalen - trainlen

    training_timeseries = data[n][:trainlen]
    test_timeseries_set = [data[n][trainlen:]]

    plt.subplot(N,1,i+1)
    
    plt.plot(time[n][:trainlen], training_timeseries[:, 0], '-', color=Black,label='Train')
    plt.plot(time[n][trainlen:], test_timeseries_set[0][:, 0], '--', color=Gray, label='Test')

    plt.xlabel(r'$L_{timeseries}$', fontsize=16)
    plt.ylabel(fr'$a_{1}$', fontsize=16)
    
    plt.legend()
    plt.grid()

# %%
n = 60 - 1
datalen = len(time[n])
trainlen = datalen - 935
testlen = datalen - trainlen

training_timeseries = data[n][:trainlen]
test_timeseries_set = [data[n][trainlen:]]

spectral_radius_values = [0.5]
sparsity_values = [0.9]

esn, errors = optimal_esn(
    training_timeseries, 
    test_timeseries_set, 
    spectral_radius_values=spectral_radius_values, 
    sparsity_values=sparsity_values,
    n_reservoir=1500, 
    return_errors=True, 
    random_seed_starts_at=42, 
    trial_number=1
);

model = EsnForecaster(
    n_reservoir=1500,
    spectral_radius=spectral_radius_values[0],
    sparsity=sparsity_values[0],
    regularization='noise',
    use_bias=True,
    lambda_r=0.001,
    random_state=42
)

model.fit(training_timeseries);

N = 1

plt.figure(figsize=(15,4*N))

for i in range(N):
    plt.subplot(N,1,i+1)
    
    plt.plot(time[n][:trainlen], training_timeseries[:, i], '-', label='Train', color = Black)
    plt.plot(time[n][trainlen:], test_timeseries_set[0][:, i], '--', label='Test', color = Gray)
    plt.plot(time[n][trainlen:], esn.predict(np.ones(testlen))[:, i], '-', label='Pred optimap_esn', color = Gainsboro)
    plt.plot(time[n][trainlen:], model.predict(testlen)[:, i], '--', label='Pred EsnForecaster', color = Gainsboro)

    plt.xlabel(r'$L_{timeseries}$', fontsize=16)
    plt.ylabel(fr'$a_{i+1}$', fontsize=16)
    
    plt.legend()
    plt.grid()
# Out:
# Spectral radius = 0.5
# 	Sparsity = 0.9
# 		Trial #42
# 			New best ESN. Error = 0.15927028656256575, spectral radius = 0.5, sparsity = 0.9

# %%
n = 66 - 1
datalen = len(time[n])
trainlen = datalen - 935
testlen = datalen - trainlen

training_timeseries = data[n][:trainlen]
test_timeseries_set = [data[n][trainlen:]]

spectral_radius_values = [0.5]
sparsity_values = [0.9]

esn, errors = optimal_esn(
    training_timeseries, 
    test_timeseries_set, 
    spectral_radius_values=spectral_radius_values, 
    sparsity_values=sparsity_values,
    n_reservoir=1500, 
    return_errors=True, 
    random_seed_starts_at=42, 
    trial_number=1
);

model = EsnForecaster(
    n_reservoir=1500,
    spectral_radius=spectral_radius_values[0],
    sparsity=sparsity_values[0],
    regularization='noise',
    use_bias=True,
    lambda_r=0.001,
    random_state=42
)

model.fit(training_timeseries);

N = 1

plt.figure(figsize=(15,4*N))

for i in range(N):
    plt.subplot(N,1,i+1)
    
    plt.plot(time[n][:trainlen], training_timeseries[:, i], '-', label='Train', color = Black)
    plt.plot(time[n][trainlen:], test_timeseries_set[0][:, i], '--', label='Test', color = Gray)
    plt.plot(time[n][trainlen:], esn.predict(np.ones(testlen))[:, i], '-', label='Pred optimap_esn', color = Gainsboro)
    plt.plot(time[n][trainlen:], model.predict(testlen)[:, i], '--', label='Pred EsnForecaster', color = Gainsboro)

    plt.xlabel(r'$L_{timeseries}$', fontsize=16)
    plt.ylabel(fr'$a_{i+1}$', fontsize=16)
    
    plt.ylim(-1.1,1.1)
    plt.legend()
    plt.grid()
# Out:
# Spectral radius = 0.5
# 	Sparsity = 0.9
# 		Trial #42
# 			New best ESN. Error = 0.25584697830974207, spectral radius = 0.5, sparsity = 0.9

# %%
N = 1

plt.figure(figsize=(15,4*N))
plt.title('pyESN')
for j in range(100):
    pred = esn.predict(np.ones(testlen))
    for i in range(N):
        plt.subplot(N,1,i+1)
        
        plt.plot(time[n][trainlen:], pred[:, i], color='#0000FF11')

        plt.xlabel(r'$L_{timeseries}$', fontsize=16)
        plt.ylabel(fr'$a_{i+1}$', fontsize=16)
        
plt.grid()

# %%
N = 1

plt.figure(figsize=(25,4*N))
plt.title('EsnForcaster')
for j in range(100):
    pred = model.predict(testlen)
    for i in range(N):
        plt.subplot(N,1,i+1)
        
        plt.plot(time[n][trainlen:], pred[:, i], color='#0000FF11')

        plt.xlabel(r'$L_{timeseries}$', fontsize=16)
        plt.ylabel(fr'$U_{i+1}$', fontsize=16)
        
plt.grid()

# %%
# %%time
error_min_set = []
len_set = []

for i in range(n_files):
    n = i
    datalen = len(time[n])
    trainlen = datalen - 935
    testlen = datalen - trainlen

    training_timeseries = data[n][:trainlen]
    test_timeseries_set = [data[n][trainlen:]]

    spectral_radius_values = [0.5]
    sparsity_values = [0.1]

    esn, errors = optimal_esn(
        training_timeseries, 
        test_timeseries_set, 
        spectral_radius_values=spectral_radius_values, 
        sparsity_values=sparsity_values,
        n_reservoir=1500, 
        return_errors=True, 
        random_seed_starts_at=42, 
        trial_number=1
    )
    
    error_min_set.append(min(errors[0][0]))
    len_set.append(datalen)
# Out:
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.25743537612093703, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2746679118699332, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2624509195319023, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.25446908802169366, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.24634027585926996, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.9461009054538948, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.17997081914279553, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.19869263435063383, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.10358955126426853, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.0651422241169633, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.00340660151360603, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.23359958401170125, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.03904259688822028, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2194989317121138, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.25471914309647153, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.24482540356865073, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.20729257906394713, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.19419330410506824, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.27794886265104596, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2264516001290041, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.21768825352059173, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 1.501045535067093, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.19660489994048974, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2305222792368237, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.341879785332591, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.18518898176214554, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.19986829190082114, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.17461857415709647, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.24131605386171875, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2295439757610709, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 1.6396557191963237, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.035426760876658366, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.013724218746786171, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.22534042961326411, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2066797396604357, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.19565554045868253, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.23493038643622768, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2264496803158876, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2410824268865214, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.24697895053680183, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.26504300807691594, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.24608554783228387, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.14238014591795584, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.07232921527533695, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.012958356939681342, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.27226447116585456, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.20367720207332632, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 1.5230293076004695, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.17500361185089727, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.23951317915779569, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.17643617604833964, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.22981181675893794, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.22635312996038226, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.19617031237174734, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2322722459025823, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.21308053538624913, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.21665878929277751, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.011432065679324782, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.22515108131266237, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.019526153996238922, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.07903422157973988, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.22123494382559053, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.1782405100564777, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.17924037723639558, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.22149990937624428, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2560119163931381, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.13477405447148325, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.18943156113436624, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.23373672015475158, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2452328638254913, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.19578475437387968, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.1437458381976236, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.24608462160004083, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.21015299396113452, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.26023510782194426, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.23719965552830002, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.22486814665267127, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.23995285788089865, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2115189659341873, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.18047835116600722, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.23115412976897728, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.019749258544876087, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2152128150649413, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.22161144394854254, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.1288338829837484, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.229038449117254, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2552521705824719, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.018441246351879916, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.24093371153174822, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.3217299239601632, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.24283807590341083, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.21685830128170808, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.13170692518375102, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.12693563262937363, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.22532655393533008, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.29654195558745844, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.24155309709689066, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2423208982084418, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.2735020853329566, spectral radius = 0.5, sparsity = 0.1
# Spectral radius = 0.5
# 	Sparsity = 0.1
# 		Trial #42
# 			New best ESN. Error = 0.07853408323598934, spectral radius = 0.5, sparsity = 0.1
# CPU times: total: 28min 46s
# Wall time: 4min 52s

# %%
# %%time
error_min_set1 = []

for i in range(n_files):
    n = i
    datalen = len(time[n])
    trainlen = datalen - 935
    testlen = datalen - trainlen
    
    training_timeseries = data[n][:trainlen]
    test_timeseries_set = [data[n][trainlen:]]

    model = EsnForecaster(
        n_reservoir=1500,
        spectral_radius=spectral_radius_values[0],
        sparsity=sparsity_values[0],
        regularization='noise',
        lambda_r=0.001,
        use_bias=True,
        random_state=42
        )
        
    model.fit(training_timeseries)
    error_min_set1.append(
        np.sqrt(np.mean((model.predict(test_timeseries_set[0].shape[0]) - test_timeseries_set)**2))
    )
# Out:
# CPU times: total: 21min 41s
# Wall time: 3min 37s

# %%
df = pd.DataFrame(
    {
        'n_file': [i+1 for i in range(n_files)],
        'len':len_set, 
        'Loss_pyESN': error_min_set,
        'Loss_EsnForecaster':error_min_set1
    }
)

df = df.sort_values(by=['len'])

# %%
plt.figure(figsize=(15,6))
plt.plot(df.len, df.Loss_pyESN, '*-', color=Black, label='Loss pyESN')
plt.plot(df.len, df.Loss_EsnForecaster, '*-', color=Silver, label='Loss skesn')

plt.semilogy();
plt.xlabel(r'$L_{timeseries}$', fontsize=16)
plt.ylabel(f'$Loss$', fontsize=16)
plt.legend()
plt.grid()
